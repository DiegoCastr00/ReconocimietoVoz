# %%
import pandas as pd 
from speakerClassifierSVM import SpeakerClassifierSVM

# %%
def main():
    data = pd.read_csv('csv/word_features.csv')
    X = data.drop('palabra', axis=1)
    y = data['palabra']
    
    # Crear y entrenar el modelo
    classifier = SpeakerClassifierSVM()
    X_test, y_test, y_pred = classifier.train(X, y)
    
    # Guardar el modelo
    classifier.save_model('speakerClassifier.joblib')
    
    # loaded_classifier = SpeakerClassifierSVM.load_model('speakerClassifier.joblib')
    # predictions = loaded_classifier.predict(new_data)

if __name__ == "__main__":
    main()
# Out:
# Entrenando modelo SVM...
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#         alto       0.97      0.95      0.96        40
#         baja       0.93      1.00      0.96        40
#         casa       1.00      1.00      1.00        40
#         cero       1.00      0.97      0.99        40
#         frio       0.95      0.97      0.96        40
#          luz       0.97      0.97      0.97        40
#           no       0.97      0.97      0.97        40
#         ocho       1.00      0.93      0.96        40
#           si       1.00      1.00      1.00        40
#          uno       0.95      0.97      0.96        40
#
#     accuracy                           0.97       400
#    macro avg       0.98      0.97      0.98       400
# weighted avg       0.98      0.97      0.98       400
